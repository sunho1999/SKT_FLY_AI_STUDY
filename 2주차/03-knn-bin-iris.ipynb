# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/SKT FLY AI/2주차/iris_bin.csv")

# %%
df.head(5)
# Out:
#    Id  sepal_length  sepal_width      species
# 0   1           5.1          3.5  Iris-setosa
# 1   2           4.9          3.0  Iris-setosa
# 2   3           4.7          3.2  Iris-setosa
# 3   4           4.6          3.1  Iris-setosa
# 4   5           5.0          3.6  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            100 non-null    int64
#  1   sepal_length  100 non-null    float64
#  2   sepal_width   100 non-null    float64
#  3   species       100 non-null    object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.2+ KB

# %%
df.describe()
# Out:
#                Id  sepal_length  sepal_width
# count  100.000000    100.000000   100.000000
# mean    50.500000      5.471000     3.094000
# std     29.011492      0.641698     0.476057
# min      1.000000      4.300000     2.000000
# 25%     25.750000      5.000000     2.800000
# 50%     50.500000      5.400000     3.050000
# 75%     75.250000      5.900000     3.400000
# max    100.000000      7.000000     4.400000

# %%
# 결측치(Missing value)

df.isna().sum(axis=0)
# Out:
# Id              0
# sepal_length    0
# sepal_width     0
# species         0
# dtype: int64

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.drop(columns = 'Id')
df
# Out:
#     sepal_length  sepal_width          species
# 0            5.1          3.5      Iris-setosa
# 1            4.9          3.0      Iris-setosa
# 2            4.7          3.2      Iris-setosa
# 3            4.6          3.1      Iris-setosa
# 4            5.0          3.6      Iris-setosa
# ..           ...          ...              ...
# 95           5.7          3.0  Iris-versicolor
# 96           5.7          2.9  Iris-versicolor
# 97           6.2          2.9  Iris-versicolor
# 98           5.1          2.5  Iris-versicolor
# 99           5.7          2.8  Iris-versicolor
#
# [100 rows x 3 columns]

# %%
df = df.sample(frac = 1)

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#     sepal_length  sepal_width          species
# 0            4.8          3.1      Iris-setosa
# 1            6.9          3.1  Iris-versicolor
# 2            5.1          2.5  Iris-versicolor
# 3            5.1          3.5      Iris-setosa
# 4            6.2          2.9  Iris-versicolor
# ..           ...          ...              ...
# 95           5.8          4.0      Iris-setosa
# 96           5.0          3.4      Iris-setosa
# 97           6.6          2.9  Iris-versicolor
# 98           5.6          3.0  Iris-versicolor
# 99           4.9          3.0      Iris-setosa
#
# [100 rows x 3 columns]

# %%
X = df[:80]
y = df[80:]

X.shape
# Out:
# (80, 3)

# %%
y.shape
# Out:
# (20, 3)

# %%
X_target = X.species
X_train = X[['sepal_length','sepal_width']]

# %%
X.species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor'], dtype=object)

# %%
X_target = X_target.map({'Iris-setosa': 0, 'Iris-versicolor':1})

# %%
X_train
# Out:
#     sepal_length  sepal_width
# 0            4.8          3.1
# 1            6.9          3.1
# 2            5.1          2.5
# 3            5.1          3.5
# 4            6.2          2.9
# ..           ...          ...
# 75           5.7          2.6
# 76           5.1          3.5
# 77           5.7          2.8
# 78           4.4          2.9
# 79           5.0          2.3
#
# [80 rows x 2 columns]

# %%
X_target
# Out:
# 0     0
# 1     1
# 2     1
# 3     0
# 4     1
#      ..
# 75    1
# 76    0
# 77    1
# 78    0
# 79    1
# Name: species, Length: 80, dtype: int64

# %%
X_train = X_train.values
X_target = X_target.values

# %%
X_train
# Out:
# array([[4.8, 3.1],
#        [6.9, 3.1],
#        [5.1, 2.5],
#        [5.1, 3.5],
#        [6.2, 2.9],
#        [6. , 2.9],
#        [5.5, 3.5],
#        [6.1, 3. ],
#        [4.7, 3.2],
#        [5.5, 4.2],
#        [5.5, 2.6],
#        [5.3, 3.7],
#        [5.1, 3.3],
#        [6.1, 2.9],
#        [4.8, 3.4],
#        [6.7, 3.1],
#        [5.1, 3.8],
#        [5. , 3.2],
#        [6.1, 2.8],
#        [6.5, 2.8],
#        [4.6, 3.2],
#        [6.2, 2.2],
#        [5.8, 2.7],
#        [5.2, 3.4],
#        [5.7, 2.9],
#        [5.4, 3. ],
#        [5.7, 2.8],
#        [6.7, 3. ],
#        [6. , 3.4],
#        [5.6, 3. ],
#        [4.6, 3.1],
#        [4.8, 3. ],
#        [4.8, 3. ],
#        [6.7, 3.1],
#        [4.6, 3.6],
#        [5.2, 3.5],
#        [5.6, 2.9],
#        [5. , 3.6],
#        [5. , 3.5],
#        [5.1, 3.8],
#        [6.6, 3. ],
#        [5.6, 2.5],
#        [6.8, 2.8],
#        [5.2, 4.1],
#        [4.7, 3.2],
#        [5.2, 2.7],
#        [6.4, 2.9],
#        [6. , 2.2],
#        [4.4, 3. ],
#        [6.1, 2.8],
#        [6.3, 3.3],
#        [5.1, 3.7],
#        [5. , 3.5],
#        [5.5, 2.3],
#        [4.4, 3.2],
#        [5.6, 2.7],
#        [5.4, 3.7],
#        [5. , 3.3],
#        [5.7, 4.4],
#        [5.5, 2.5],
#        [4.9, 2.4],
#        [6.3, 2.5],
#        [5.7, 3. ],
#        [5.4, 3.4],
#        [5.9, 3. ],
#        [5.1, 3.4],
#        [5.4, 3.4],
#        [4.9, 3.1],
#        [4.3, 3. ],
#        [7. , 3.2],
#        [5.5, 2.4],
#        [5.4, 3.9],
#        [5.8, 2.6],
#        [4.6, 3.4],
#        [5.4, 3.9],
#        [5.7, 2.6],
#        [5.1, 3.5],
#        [5.7, 2.8],
#        [4.4, 2.9],
#        [5. , 2.3]])

# %%
# 베이스 모델 학습
from sklearn.neighbors import KNeighborsClassifier

clf = KNeighborsClassifier()
clf.fit(X_train,X_target)
# Out:
# KNeighborsClassifier()

# %%
clf
# Out:
# KNeighborsClassifier()

# %%
y_target = y.species

# %%
y_train =  y[['sepal_length','sepal_width']]
y_target = y_target.map({'Iris-setosa': 0, 'Iris-versicolor':1})

# %%
y_target
# Out:
# 80    1
# 81    0
# 82    0
# 83    0
# 84    1
# 85    0
# 86    0
# 87    0
# 88    0
# 89    1
# 90    1
# 91    1
# 92    0
# 93    1
# 94    1
# 95    0
# 96    0
# 97    1
# 98    1
# 99    0
# Name: species, dtype: int64

# %%
y_target = y_target.values
y_train = y_train.values

# %%
# 예측 진행

y_pred = clf.predict(y_train)

# %%
# 정확도 평가

np.sum(y_pred == y_target) / len(y_pred)
# Out:
# 0.95

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score,f1_score


acc = accuracy_score(y_target,y_pred) # 정답값, 예측값
recall = recall_score(y_target,y_pred) # 정답값, 예측값
precision = precision_score(y_target,y_pred) # 정답값, 예측값
f1 = f1_score(y_target,y_pred) # 정답값, 예측값

print(f'accuracy : {acc}')
print(f'recall : {round(recall,3)}')
print(f'precision : {round(precision,3)}')
print(f'f1 : {round(f1,3)}')
# Out:
# accuracy : 0.95
# recall : 1.0
# precision : 0.9
# f1 : 0.947

# %%
score = []

for k in range(3,80):
  clf = KNeighborsClassifier(n_neighbors = k)
  clf.fit(X_train,X_target)
  y_pred = clf.predict(y_train)
  acc = accuracy_score(y_target,y_pred) # 정답값, 예측값
  score.append(acc)
print(f'max_accuracy: {max(score)}')
# Out:
# max_accuracy: 1.0

# %%
plt.plot(range(3,80),score)
plt.show()
